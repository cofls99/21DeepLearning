# %% [markdown]
# # NVIDIA GPU 확인

# %% [markdown]
# ## STEP 1: 장치 관리자 > 디스플레이 어댑터
# - NVIDIA GPU 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## STEP 2: [Compute Capability, 버전 확인](https://developer.nvidia.com/cuda-gpus)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## STEP 3: [GPU Compute Capability에 맞는 CUDA SDK 버전을 확인](https://en.wikipedia.org/wiki/CUDA#GPUs_supported)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # NVIDIA GPU 설치

# %% [markdown]
# ## STEP 4: [NVIDIA Graphic Driver 설치](https://www.nvidia.com/en-us/drivers/)
# - 이때, Download Type은 Game Ready Driver (GRD), Studio Driver (SD)를 선택해야 되는데, CUDA 설치 시 특정 type이 필요하다는 내용이 없습니다.
# - 일반적으로 설치하는 드라이버인 GRD로 설치하면 실행에 문제가 없습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## STEP 5: [CUDA 설치](https://developer.nvidia.com/cuda-downloads?target_os=Windows&target_arch=x86_64&target_version=11&target_type=exe_local)
# - `STEP 3`에서 확인한 CUDA 버전에 맞게 옵션을 선택해서 설치하면 됩니다.
# - [이전 버전 CUDA](https://developer.nvidia.com/cuda-toolkit-archive)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## STEP 6: [cuDNN 설치](https://developer.nvidia.com/cudnn-downloads?target_os=Windows&target_arch=x86_64&target_version=10)
# - [NVIDIA Developer 페이지](https://developer.nvidia.com/cudnn-downloads)를 접속해서, 새롭게 계정을 만들고 버전에 맞는 cuDNN을 설치하면 됩니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## STEP 7: 시스템 환경 변수 > 환경 변수 편집

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # NVIDIA GPU 설치 확인

# %% [markdown]
# ## CMD 접속 후 `CUDA Version` 확인
# ```shell
# nvcc --version
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CMD 접속 후 `CUDA Version` 확인
# ```shell
# nvidia-smi
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 윈도우 다시 시작

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Pytorch GPU

# %% [markdown]
# ## Python 가상환경 생성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [Pytorch GPU 설치](https://pytorch.org/get-started/locally/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pytorch GPU 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)
