# %% [markdown]
# # [RunPod](https://www.runpod.io/)

# %% [markdown]
# ## [RunPod란?](https://muns-da2.tistory.com/670)
# - 최근 LLM과 관련된 Dacon 프로젝트를 수행하게 되면, 개인용 컴퓨팅 환경은 그 성능에 한계가 있다는 큰 문제가 있습니다.
# - 런팟은 클라우드 기반의 GPU 컴퓨팅 플랫폼으로 딥러닝 모델 학습이나 AI 프로젝트 실행에 필요한 고성능 컴퓨팅 자원을 제공합니다.
# - 또한, Multi-GPU를 활용해보고 싶은 분들에게도 런팟은 다양한 GPU를 제공하기 때문에 이를 기반으로 더 효율적이고 빠른 실습 환경을 구축할 수 있고 실제 산업 현장에서 사용되는 고성능 컴퓨팅 환경을 경험할 수 있다는 장점이 있습니다.

# %% [markdown]
# ## 제공되는 딥러닝 또는 서비스 모듈

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 제공되는 GPU 컴퓨팅 환경
# - 런팟에서 제공되는 환경은 80GB+ VRAM, 80GB VRAM, 48GB VRAM, 24GB+ VRAM를 기준으로 다양한 서비스 환경이 구성되어 있습니다.
# - 물론 성능이 높아질 수록 시간당 부과되는 요금이 증가합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [RunPod 사용법](https://webnautes.tistory.com/2393)

# %% [markdown]
# ##  [RunPod 회원가입](https://www.runpod.io/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [결제 수단 등록](https://www.runpod.io/console/user/billing)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## [Pod 사용하기](https://www.runpod.io/console/pods)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Cloud 선택
# - `Secure Cloude`: 보안이 필요한 경우 & 비용이 비쌈
# - `Community Cloude`: 보안이 필요하지 않은 경우 & 비용이 저렴

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pod(가상컴퓨터) 선택
# - 가장 중요한 것은 `다운로드 속도`입니다.
#   - 런팟은 분당 비용이 발생하는데, 사용할 때마다 매번 관련 라이브러리를 다운로드 받아야하기 때문입니다.
# - `비용` & `GPU VRAN`을 고려하여 적절한 Pod 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pod 설정 선택
# - Pod 명
# - Template(딥러닝 모듈)
# - CPU Count
# - Instance Pricing
#   - `On-Demand`:
#     - 인스턴스 사용 방식 중, 온디맨드 방식은 흔히 전세 방식이라고 할 수 있다.
#     - 가장 비싸지만, 안정적으로 구매한 리소스를 사용할 수 있다.
#   - `Spot`:
#     - 온디맨드 방식과 다르게, 남는 인스턴스를 경매 방식을 통해 구매하고 사용한다.
#     - 만약 내가 spot 인스턴스를 사용하고 있더라고 다른 사용자가 나보다 높은 가격을 불러 해당 리소스를 산다면 나의 인스턴스가 곧바로 중단되므로 불안정하다는 단점이 있다.
#     - 하지만 모든 방법 중 가장 저렴하다는 장점이 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pod 접속

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 사용하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pod 삭제하기

# %% [markdown]
# ### Pod 중지
# - 중지 상태에서도 비용이 발생함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pod 삭제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
